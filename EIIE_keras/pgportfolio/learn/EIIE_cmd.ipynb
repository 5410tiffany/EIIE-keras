# %%
import os
os.chdir('D:/EIIE_keras/')

from pgportfolio.learn.tradertrainer import TraderTrainer
from pgportfolio.tools.configprocess import load_config
         
config_2 = load_config(2)
train_dir = "train_package"

s_path = "./" + train_dir + "/" + '2'+ "/netfile"
l_path = "./" + train_dir + "/" + '2' + "/tensorboard"

t_trainer = TraderTrainer(config_2, save_path=s_path, device='gpu')

#%%

import logging

console_level = logging.INFO
logfile_level = logging.DEBUG

logging.basicConfig(filename=l_path.replace("tensorboard","programlog"), level=console_level)
console = logging.StreamHandler()
console.setLevel(console_level)
logging.getLogger().addHandler(console)

t_trainer.train_net(log_file_dir = l_path, index='2')
# Out:
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Joukey\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\helpers\summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\helpers\trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# so gan here 1
# D:\EIIE_keras\database\Data.db
# 1435680000 1498838400.0 1800 109 30 5e-05 poloniex 11 31 3 0.08 False False False
# D:\EIIE_keras\pgportfolio\marketdata\datamatrices.py:55: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   features=type_list)
# D:\EIIE_keras\pgportfolio\marketdata\globaldatamatrix.py:119: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   panel = panel_fillna(panel, "both")
# it is so shit
# so gan here 2
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:63: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:63: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\initializations.py:119: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tflearn\initializations.py:119: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:507: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:507: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:139: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:139: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:42: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\nnagent.py:42: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# im here~
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:156: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:156: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:156: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:161: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:161: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:161: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
# INFO:tensorflow:Summary name Conv2D/W:0 is illegal; using Conv2D/W_0 instead.
# INFO:tensorflow:Summary name Conv2D/W:0 is illegal; using Conv2D/W_0 instead.
# Summary name Conv2D/W:0 is illegal; using Conv2D/W_0 instead.
# INFO:tensorflow:Summary name Conv2D/b:0 is illegal; using Conv2D/b_0 instead.
# INFO:tensorflow:Summary name Conv2D/b:0 is illegal; using Conv2D/b_0 instead.
# Summary name Conv2D/b:0 is illegal; using Conv2D/b_0 instead.
# INFO:tensorflow:Summary name Conv2D_1/W:0 is illegal; using Conv2D_1/W_0 instead.
# INFO:tensorflow:Summary name Conv2D_1/W:0 is illegal; using Conv2D_1/W_0 instead.
# Summary name Conv2D_1/W:0 is illegal; using Conv2D_1/W_0 instead.
# INFO:tensorflow:Summary name Conv2D_1/b:0 is illegal; using Conv2D_1/b_0 instead.
# INFO:tensorflow:Summary name Conv2D_1/b:0 is illegal; using Conv2D_1/b_0 instead.
# Summary name Conv2D_1/b:0 is illegal; using Conv2D_1/b_0 instead.
# INFO:tensorflow:Summary name Conv2D_2/W:0 is illegal; using Conv2D_2/W_0 instead.
# INFO:tensorflow:Summary name Conv2D_2/W:0 is illegal; using Conv2D_2/W_0 instead.
# Summary name Conv2D_2/W:0 is illegal; using Conv2D_2/W_0 instead.
# INFO:tensorflow:Summary name Conv2D_2/b:0 is illegal; using Conv2D_2/b_0 instead.
# INFO:tensorflow:Summary name Conv2D_2/b:0 is illegal; using Conv2D_2/b_0 instead.
# Summary name Conv2D_2/b:0 is illegal; using Conv2D_2/b_0 instead.
# INFO:tensorflow:Summary name btc_bias:0 is illegal; using btc_bias_0 instead.
# INFO:tensorflow:Summary name btc_bias:0 is illegal; using btc_bias_0 instead.
# Summary name btc_bias:0 is illegal; using btc_bias_0 instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter:0/gradient is illegal; using gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter:0/gradient is illegal; using gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter_0/gradient instead.
# Summary name gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter:0/gradient is illegal; using gradients_1/Conv2D/Conv2D_grad/Conv2DBackpropFilter_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# Summary name gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/AddN_2:0/gradient is illegal; using gradients_1/AddN_2_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/AddN_2:0/gradient is illegal; using gradients_1/AddN_2_0/gradient instead.
# Summary name gradients_1/AddN_2:0/gradient is illegal; using gradients_1/AddN_2_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# Summary name gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_1/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/AddN_1:0/gradient is illegal; using gradients_1/AddN_1_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/AddN_1:0/gradient is illegal; using gradients_1/AddN_1_0/gradient instead.
# Summary name gradients_1/AddN_1:0/gradient is illegal; using gradients_1/AddN_1_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# Summary name gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad:0/gradient is illegal; using gradients_1/Conv2D_2/BiasAdd_grad/BiasAddGrad_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Tile_grad/Sum:0/gradient is illegal; using gradients_1/Tile_grad/Sum_0/gradient instead.
# INFO:tensorflow:Summary name gradients_1/Tile_grad/Sum:0/gradient is illegal; using gradients_1/Tile_grad/Sum_0/gradient instead.
# Summary name gradients_1/Tile_grad/Sum:0/gradient is illegal; using gradients_1/Tile_grad/Sum_0/gradient instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:167: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# WARNING:tensorflow:From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:167: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# From D:\EIIE_keras\pgportfolio\learn\tradertrainer.py:167: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# ==============================
# step 0
# ------------------------------
# the portfolio value on test set is 1.9771805
# log_mean is 0.00024555824
# loss_value is -0.000246
# log mean without commission fee is 0.000271
#
# ==============================
#
# ==============================
# step 1000
# ------------------------------
# the portfolio value on test set is 2.146251
# log_mean is 0.00027511697
# loss_value is -0.000275
# log mean without commission fee is 0.000317
#
# ==============================
#
# ==============================
# step 2000
# ------------------------------
# the portfolio value on test set is 2.3066676
# log_mean is 0.0003010826
# loss_value is -0.000301
# log mean without commission fee is 0.000361
#
# ==============================
#
# ==============================
# step 3000
# ------------------------------
# the portfolio value on test set is 2.5053072
# log_mean is 0.00033083928
# loss_value is -0.000331
# log mean without commission fee is 0.000413
#
# ==============================
#
# ==============================
# step 4000
# ------------------------------
# the portfolio value on test set is 2.956162
# log_mean is 0.00039045172
# loss_value is -0.000390
# log mean without commission fee is 0.000517
#
# ==============================
#
# ==============================
# step 5000
# ------------------------------
# the portfolio value on test set is 3.137471
# log_mean is 0.00041189368
# loss_value is -0.000412
# log mean without commission fee is 0.000555
#
# ==============================
#
# ==============================
# step 6000
# ------------------------------
# the portfolio value on test set is 3.8934286
# log_mean is 0.00048965844
# loss_value is -0.000490
# log mean without commission fee is 0.000685
#
# ==============================
#
# ==============================
# step 7000
# ------------------------------
# the portfolio value on test set is 6.804255
# log_mean is 0.00069076015
# loss_value is -0.000691
# log mean without commission fee is 0.001010
#
# ==============================
#
# ==============================
# step 8000
# ------------------------------
# the portfolio value on test set is 7.699254
# log_mean is 0.00073527516
# loss_value is -0.000735
# log mean without commission fee is 0.001082
#
# ==============================
#
# ==============================
# step 9000
# ------------------------------
# the portfolio value on test set is 9.162583
# log_mean is 0.0007979566
# loss_value is -0.000798
# log mean without commission fee is 0.001187
#
# ==============================
#
# ==============================
# step 10000
# ------------------------------
# the portfolio value on test set is 12.469775
# log_mean is 0.0009089727
# loss_value is -0.000909
# log mean without commission fee is 0.001380
#
# ==============================
#
# ==============================
# step 11000
# ------------------------------
# the portfolio value on test set is 12.717514
# log_mean is 0.0009160596
# loss_value is -0.000916
# log mean without commission fee is 0.001392
#
# ==============================
#
# ==============================
# step 12000
# ------------------------------
# the portfolio value on test set is 14.008485
# log_mean is 0.0009508872
# loss_value is -0.000951
# log mean without commission fee is 0.001457
#
# ==============================
#
# ==============================
# step 13000
# ------------------------------
# the portfolio value on test set is 16.172085
# log_mean is 0.0010026249
# loss_value is -0.001003
# log mean without commission fee is 0.001562
#
# ==============================
#
# ==============================
# step 14000
# ------------------------------
# the portfolio value on test set is 20.118668
# log_mean is 0.0010812861
# loss_value is -0.001081
# log mean without commission fee is 0.001724
#
# ==============================
#
# ==============================
# step 15000
# ------------------------------
# the portfolio value on test set is 27.157614
# log_mean is 0.0011893577
# loss_value is -0.001189
# log mean without commission fee is 0.001965
#
# ==============================
#
# ==============================
# step 16000
# ------------------------------
# the portfolio value on test set is 33.343002
# log_mean is 0.0012632738
# loss_value is -0.001263
# log mean without commission fee is 0.002152
#
# ==============================
#
# ==============================
# step 17000
# ------------------------------
# the portfolio value on test set is 40.97561
# log_mean is 0.0013375279
# loss_value is -0.001337
# log mean without commission fee is 0.002345
#
# ==============================
#
# ==============================
# step 18000
# ------------------------------
# the portfolio value on test set is 46.14127
# log_mean is 0.0013802974
# loss_value is -0.001380
# log mean without commission fee is 0.002458
#
# ==============================
#
# ==============================
# step 19000
# ------------------------------
# the portfolio value on test set is 46.75547
# log_mean is 0.0013850624
# loss_value is -0.001385
# log mean without commission fee is 0.002493
#
# ==============================
#
# ==============================
# step 20000
# ------------------------------
# the portfolio value on test set is 52.74566
# log_mean is 0.0014284875
# loss_value is -0.001428
# log mean without commission fee is 0.002642
#
# ==============================
#
# ==============================
# step 21000
# ------------------------------
# the portfolio value on test set is 54.89156
# log_mean is 0.0014428532
# loss_value is -0.001443
# log mean without commission fee is 0.002718
#
# ==============================
#
# ==============================
# step 22000
# ------------------------------
# the portfolio value on test set is 58.401997
# log_mean is 0.001465184
# loss_value is -0.001465
# log mean without commission fee is 0.002831
#
# ==============================
#
# ==============================
# step 23000
# ------------------------------
# the portfolio value on test set is 55.649357
# log_mean is 0.001447791
# loss_value is -0.001448
# log mean without commission fee is 0.002831
#
# ==============================
#
# ==============================
# step 24000
# ------------------------------
# the portfolio value on test set is 50.200794
# log_mean is 0.0014106741
# loss_value is -0.001410
# log mean without commission fee is 0.002785
#
# ==============================
#
# ==============================
# step 25000
# ------------------------------
# the portfolio value on test set is 53.335842
# log_mean is 0.0014324957
# loss_value is -0.001432
# log mean without commission fee is 0.002852
#
# ==============================
#
# ==============================
# step 26000
# ------------------------------
# the portfolio value on test set is 48.57413
# log_mean is 0.0013988088
# loss_value is -0.001399
# log mean without commission fee is 0.002798
#
# ==============================
#
# ==============================
# step 27000
# ------------------------------
# the portfolio value on test set is 47.980705
# log_mean is 0.0013943803
# loss_value is -0.001394
# log mean without commission fee is 0.002800
#
# ==============================
#
# ==============================
# step 28000
# ------------------------------
# the portfolio value on test set is 50.31918
# log_mean is 0.0014115222
# loss_value is -0.001411
# log mean without commission fee is 0.002853
#
# ==============================
#
# ==============================
# step 29000
# ------------------------------
# the portfolio value on test set is 49.57869
# log_mean is 0.0014061824
# loss_value is -0.001406
# log mean without commission fee is 0.002871
#
# ==============================
#
# ==============================
# step 30000
# ------------------------------
# the portfolio value on test set is 48.721138
# log_mean is 0.0013998975
# loss_value is -0.001400
# log mean without commission fee is 0.002892
#
# ==============================
#
# ==============================
# step 31000
# ------------------------------
# the portfolio value on test set is 48.32821
# log_mean is 0.0013969798
# loss_value is -0.001397
# log mean without commission fee is 0.002905
#
# ==============================
#
# ==============================
# step 32000
# ------------------------------
# the portfolio value on test set is 51.533024
# log_mean is 0.0014201093
# loss_value is -0.001420
# log mean without commission fee is 0.002959
#
# ==============================
#
# ==============================
# step 33000
# ------------------------------
# the portfolio value on test set is 51.01183
# log_mean is 0.0014164472
# loss_value is -0.001416
# log mean without commission fee is 0.002980
#
# ==============================
# ==============================
# step 34000
# ------------------------------
# the portfolio value on test set is 51.077003
# log_mean is 0.0014169072
# loss_value is -0.001417
# log mean without commission fee is 0.002981
#
# ==============================
#
# ==============================
# step 35000
# ------------------------------
# the portfolio value on test set is 50.868877
# log_mean is 0.0014154363
# loss_value is -0.001415
# log mean without commission fee is 0.003015
#
# ==============================
#
# ==============================
# step 36000
# ------------------------------
# the portfolio value on test set is 49.578564
# log_mean is 0.0014061804
# loss_value is -0.001406
# log mean without commission fee is 0.003014
#
# ==============================
#
# ==============================
# step 37000
# ------------------------------
# the portfolio value on test set is 47.752823
# log_mean is 0.001392665
# loss_value is -0.001392
# log mean without commission fee is 0.003019
#
# ==============================
#
# ==============================
# step 38000
# ------------------------------
# the portfolio value on test set is 49.23493
# log_mean is 0.0014036754
# loss_value is -0.001403
# log mean without commission fee is 0.003058
#
# ==============================
#
# ==============================
# step 39000
# ------------------------------
# the portfolio value on test set is 50.167305
# log_mean is 0.0014104337
# loss_value is -0.001410
# log mean without commission fee is 0.003080
#
# ==============================
#
# ==============================
# step 40000
# ------------------------------
# the portfolio value on test set is 48.046867
# log_mean is 0.0013948762
# loss_value is -0.001395
# log mean without commission fee is 0.003039
#
# ==============================
#
# ==============================
# step 41000
# ------------------------------
# the portfolio value on test set is 49.75533
# log_mean is 0.0014074645
# loss_value is -0.001407
# log mean without commission fee is 0.003094
#
# ==============================
#
# ==============================
# step 42000
# ------------------------------
# the portfolio value on test set is 47.23007
# log_mean is 0.0013887
# loss_value is -0.001388
# log mean without commission fee is 0.003085
#
# ==============================
#
# ==============================
# step 43000
# ------------------------------
# the portfolio value on test set is 46.66936
# log_mean is 0.0013843974
# loss_value is -0.001384
# log mean without commission fee is 0.003086
#
# ==============================
#
# ==============================
# step 44000
# ------------------------------
# the portfolio value on test set is 46.274185
# log_mean is 0.001381334
# loss_value is -0.001381
# log mean without commission fee is 0.003097
#
# ==============================
#
# ==============================
# step 45000
# ------------------------------
# the portfolio value on test set is 48.052227
# log_mean is 0.001394917
# loss_value is -0.001395
# log mean without commission fee is 0.003134
#
# ==============================
#
# ==============================
# step 46000
# ------------------------------
# the portfolio value on test set is 45.51256
# log_mean is 0.0013753554
# loss_value is -0.001375
# log mean without commission fee is 0.003103
#
# ==============================
#
# ==============================
# step 47000
# ------------------------------
# the portfolio value on test set is 43.940727
# log_mean is 0.0013626943
# loss_value is -0.001362
# log mean without commission fee is 0.003108
#
# ==============================
#
# ==============================
# step 48000
# ------------------------------
# the portfolio value on test set is 44.270638
# log_mean is 0.0013653894
# loss_value is -0.001365
# log mean without commission fee is 0.003128
#
# ==============================
#
# ==============================
# step 49000
# ------------------------------
# the portfolio value on test set is 40.894558
# log_mean is 0.001336814
# loss_value is -0.001336
# log mean without commission fee is 0.003108
#
# ==============================
#
# ==============================
# step 50000
# ------------------------------
# the portfolio value on test set is 42.06734
# log_mean is 0.0013469988
# loss_value is -0.001347
# log mean without commission fee is 0.003165
#
# ==============================
#
# ==============================
# step 51000
# ------------------------------
# the portfolio value on test set is 40.613476
# log_mean is 0.0013343301
# loss_value is -0.001334
# log mean without commission fee is 0.003145
#
# ==============================
#
# ==============================
# step 52000
# ------------------------------
# the portfolio value on test set is 40.773056
# log_mean is 0.0013357423
# loss_value is -0.001335
# log mean without commission fee is 0.003174
#
# ==============================
#
# ==============================
# step 53000
# ------------------------------
# the portfolio value on test set is 38.377674
# log_mean is 0.0013139322
# loss_value is -0.001314
# log mean without commission fee is 0.003148
#
# ==============================
#
# ==============================
# step 54000
# ------------------------------
# the portfolio value on test set is 39.141663
# log_mean is 0.001321033
# loss_value is -0.001321
# log mean without commission fee is 0.003215
#
# ==============================
#
# ==============================
# step 55000
# ------------------------------
# the portfolio value on test set is 39.19633
# log_mean is 0.0013215363
# loss_value is -0.001321
# log mean without commission fee is 0.003242
#
# ==============================
#
# ==============================
# step 56000
# ------------------------------
# the portfolio value on test set is 39.42209
# log_mean is 0.0013236053
# loss_value is -0.001323
# log mean without commission fee is 0.003248
#
# ==============================
#
# ==============================
# step 57000
# ------------------------------
# the portfolio value on test set is 41.16574
# log_mean is 0.0013391947
# loss_value is -0.001339
# log mean without commission fee is 0.003279
#
# ==============================
#
# ==============================
# step 58000
# ------------------------------
# the portfolio value on test set is 37.83222
# log_mean is 0.0013087748
# loss_value is -0.001308
# log mean without commission fee is 0.003252
#
# ==============================
#
# ==============================
# step 59000
# ------------------------------
# the portfolio value on test set is 39.791588
# log_mean is 0.001326965
# loss_value is -0.001327
# log mean without commission fee is 0.003299
#
# ==============================
#
# ==============================
# step 60000
# ------------------------------
# the portfolio value on test set is 37.40187
# log_mean is 0.0013046556
# loss_value is -0.001304
# log mean without commission fee is 0.003306
#
# ==============================
#
# ==============================
# step 61000
# ------------------------------
# the portfolio value on test set is 34.53228
# log_mean is 0.001275899
# loss_value is -0.001275
# log mean without commission fee is 0.003269
#
# ==============================
#
# ==============================
# step 62000
# ------------------------------
# the portfolio value on test set is 32.500893
# log_mean is 0.0012540595
# loss_value is -0.001254
# log mean without commission fee is 0.003264
#
# ==============================
#
# ==============================
# step 63000
# ------------------------------
# the portfolio value on test set is 35.964462
# log_mean is 0.0012905368
# loss_value is -0.001290
# log mean without commission fee is 0.003355
#
# ==============================
#
# ==============================
# step 64000
# ------------------------------
# the portfolio value on test set is 33.004723
# log_mean is 0.0012596002
# loss_value is -0.001259
# log mean without commission fee is 0.003347
#
# ==============================
#
# ==============================
# step 65000
# ------------------------------
# the portfolio value on test set is 33.57951
# log_mean is 0.0012658187
# loss_value is -0.001265
# log mean without commission fee is 0.003375
#
# ==============================
#
# ==============================
# step 66000
# ------------------------------
# the portfolio value on test set is 38.956207
# log_mean is 0.0013193218
# loss_value is -0.001319
# log mean without commission fee is 0.003475
#
# ==============================
#
# ==============================
# step 67000
# ------------------------------
# the portfolio value on test set is 36.634777
# log_mean is 0.0012971892
# loss_value is -0.001297
# log mean without commission fee is 0.003450
#
# ==============================
# ==============================
# step 68000
# ------------------------------
# the portfolio value on test set is 35.28679
# log_mean is 0.0012836842
# loss_value is -0.001283
# log mean without commission fee is 0.003437
#
# ==============================
#
# ==============================
# step 69000
# ------------------------------
# the portfolio value on test set is 32.918106
# log_mean is 0.0012586531
# loss_value is -0.001258
# log mean without commission fee is 0.003414
#
# ==============================
#
# ==============================
# step 70000
# ------------------------------
# the portfolio value on test set is 33.841446
# log_mean is 0.0012686199
# loss_value is -0.001268
# log mean without commission fee is 0.003447
#
# ==============================
#
# ==============================
# step 71000
# ------------------------------
# the portfolio value on test set is 32.548664
# log_mean is 0.0012545887
# loss_value is -0.001254
# log mean without commission fee is 0.003451
#
# ==============================
#
# ==============================
# step 72000
# ------------------------------
# the portfolio value on test set is 35.324085
# log_mean is 0.001284064
# loss_value is -0.001284
# log mean without commission fee is 0.003523
#
# ==============================
#
# ==============================
# step 73000
# ------------------------------
# the portfolio value on test set is 30.296791
# log_mean is 0.0012287615
# loss_value is -0.001228
# log mean without commission fee is 0.003448
#
# ==============================
#
# ==============================
# step 74000
# ------------------------------
# the portfolio value on test set is 32.794674
# log_mean is 0.0012573003
# loss_value is -0.001257
# log mean without commission fee is 0.003506
#
# ==============================
#
# ==============================
# step 75000
# ------------------------------
# the portfolio value on test set is 31.631514
# log_mean is 0.0012442914
# loss_value is -0.001244
# log mean without commission fee is 0.003497
#
# ==============================
#
# ==============================
# step 76000
# ------------------------------
# the portfolio value on test set is 30.785025
# log_mean is 0.0012345203
# loss_value is -0.001234
# log mean without commission fee is 0.003511
#
# ==============================
#
# ==============================
# step 77000
# ------------------------------
# the portfolio value on test set is 29.519451
# log_mean is 0.0012193982
# loss_value is -0.001219
# log mean without commission fee is 0.003519
#
# ==============================
#
# ==============================
# step 78000
# ------------------------------
# the portfolio value on test set is 27.828047
# log_mean is 0.0011981425
# loss_value is -0.001198
# log mean without commission fee is 0.003534
#
# ==============================
#
# ==============================
# step 79000
# ------------------------------
# the portfolio value on test set is 25.946432
# log_mean is 0.0011729226
# loss_value is -0.001172
# log mean without commission fee is 0.003516
#
# ==============================
#
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# WARNING:tensorflow:From C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# From C:\Users\Joukey\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./train_package/2/netfile
# INFO:tensorflow:Restoring parameters from ./train_package/2/netfile
# Restoring parameters from ./train_package/2/netfile
# WARNING:root:the portfolio value train No.2 is 27.769428 log_mean is 0.0011973828, the training time is 460 seconds
# the portfolio value train No.2 is 27.769428 log_mean is 0.0011973828, the training time is 460 seconds
